# %% [markdown]
# ## Version III

# %% [markdown]
# \begin{align}
#     S_{0}&\sim Normal(0,1)\\
#     A_t & \sim \pi_b = Bernoulli(.5)\\
#     M_{t1}&\sim Normal(\sqrt{|S_t|}+(A_t-.5), 2.5)\\
#     M_{t2}&\sim Normal(-.5 S_t+.5(A_t-.5)*\sqrt{|S_t|}, 2.5)\\
#     R_{t}&\sim Normal( .75S_t + .75(\sqrt{|S_t|})+1.5*M_{t1}+1.5*M_{t2}+.75*(\sqrt{|M_{t1}|+|M_{t2}|})(A_t-.5)+.75(A_t-.5), 2.5)\\
#     S_{t+1}&\sim R_t\\
#     \pi_{e}&\sim Bernoulli(expit(.7*S_{t}))\\
#     a_0&=0
# \end{align}

# %% [markdown]
# \begin{align}
#     S_{0}&\sim Normal(0,1)\\
#     A_t & \sim \pi_b = Bernoulli(.5)\\
#     M_{t1}&\sim Normal(\sqrt{|S_t|}+(A_t-.5), 2.5)\\
#     M_{t2}&\sim Normal(-.5 S_t+.5(A_t-.5)*\sqrt{|S_t|}, 2.5)\\
#     R_{t}&\sim Normal( .75\{S_t + \sqrt{|S_t|}+(1+\sqrt{|M_{t1}|+|M_{t2}|})(A_t-.5)\}+1.5\{M_{t1}+M_{t2}\}, 2.5)\\
#     S_{t+1}&\sim R_t\\
#     \pi_{e}&\sim Bernoulli(expit(.7*S_{t}))\\
#     a_0&=0
# \end{align}

# %%
import pickle
with open("true_iDE_IME_DDE_DME_direct_est_stdM_2_stdS_2.txt","rb") as fp:
    Error = pickle.load(fp) 
    
import numpy as np
out = []
for t in [100,200,400,800,1600,3200,6400]:
    out.append(Error[t][100])
import pandas as pd
out = pd.DataFrame(out)
out['d0'] = out[0]-out[0].shift(-1)
out['d1'] = out[1]-out[1].shift(-1)
out['d2'] = out[2]-out[2].shift(-1)
out['d3'] = out[3]-out[3].shift(-1)
out['d4'] = out[4]-out[4].shift(-1)
out['IDE'] = out[0]-out[1]
out['IME'] = out[1]-out[2]
out['DDE'] = out[2]-out[3]
out['DME'] = out[3]-out[4]
out['IDE_d'] = out['IDE']-out['IDE'].shift(-1)
out['IME_d'] = out['IME']-out['IME'].shift(-1)
out['DDE_d'] = out['DDE']-out['DDE'].shift(-1)
out['DME_d'] = out['DME']-out['DME'].shift(-1)
out
# Out:
#           0         1         2         3         4        d0        d1  \
# 0  9.654987  7.017952  3.430960  2.230425  1.563140 -0.095837 -0.074393
# 1  9.750824  7.092345  3.472160  2.250460  1.572204 -0.049003 -0.038119
# 2  9.799826  7.130463  3.493531  2.261170  1.577720 -0.026017 -0.020453
# 3  9.825843  7.150917  3.504871  2.266380  1.579840 -0.012373 -0.009599
# 4  9.838216  7.160515  3.510318  2.269002  1.580994 -0.006407 -0.005040
# 5  9.844623  7.165555  3.513183  2.270274  1.581568 -0.003403 -0.002630
# 6  9.848026  7.168185  3.514651  2.270868  1.581837       NaN       NaN
#
#          d2        d3        d4       IDE       IME       DDE       DME  \
# 0 -0.041200 -0.020035 -0.009064  2.637035  3.586991  1.200535  0.667285
# 1 -0.021371 -0.010710 -0.005515  2.658479  3.620185  1.221699  0.678256
# 2 -0.011340 -0.005210 -0.002121  2.669363  3.636932  1.232361  0.683450
# 3 -0.005447 -0.002622 -0.001154  2.674927  3.646046  1.238490  0.686540
# 4 -0.002866 -0.001272 -0.000574  2.677701  3.650198  1.241315  0.688008
# 5 -0.001467 -0.000595 -0.000269  2.679068  3.652372  1.242910  0.688705
# 6       NaN       NaN       NaN  2.679841  3.653535  1.243782  0.689031
#
#       IDE_d     IME_d     DDE_d     DME_d
# 0 -0.021444 -0.033194 -0.021164 -0.010972
# 1 -0.010884 -0.016747 -0.010662 -0.005194
# 2 -0.005564 -0.009114 -0.006129 -0.003090
# 3 -0.002775 -0.004152 -0.002825 -0.001468
# 4 -0.001367 -0.002174 -0.001594 -0.000697
# 5 -0.000773 -0.001163 -0.000873 -0.000326
# 6       NaN       NaN       NaN       NaN

# %%
#Truncate does not matter 20 ok
import pickle
with open("estimate_additive_identity_L7_stdM_2_stdS_2.txt","rb") as fp:
    Error = pickle.load(fp)       
from plot import plot, summary
result = summary(Error, N_range = np.arange(1, 16) * 100, T_range = [25], absolute = True, true = np.array([2.679841,3.653535,1.243782,0.689031]))
plot(result,x='N')
#result.groupby(['N','estimand']).mean()[['IDE_error','IME_error','DDE_error','DME_error',
#                                         'IDE_MSE','IME_MSE','DDE_MSE','DME_MSE']]

# %%
result.groupby(['N','estimand']).mean()[['IDE_error','IME_error','DDE_error','DME_error',
                                         'IDE_MSE','IME_MSE','DDE_MSE','DME_MSE']]
# Out:
#                  IDE_error  IME_error  DDE_error  DME_error   IDE_MSE  \
# N      estimand
# 100.0  Baseline  -1.062143   0.431060        NaN        NaN -2.276941
#        Direct    -0.193624  -0.323759  -4.966798  -1.669350 -0.494864
#        IS1       -0.403803   0.273228   0.168880  -0.814238 -1.622067
#        IS2       -0.813346   0.430875        NaN        NaN -2.702863
#        MR        -0.284700  -0.577343  -2.007483  -3.316825 -0.690079
# ...                    ...        ...        ...        ...       ...
# 1500.0 Baseline  -0.583504   0.181297        NaN        NaN -1.169986
#        Direct    -1.210306  -1.383664  -1.552073  -1.378568 -2.455409
#        IS1       -0.229996   0.184608   0.145386  -0.775036 -0.609858
#        IS2       -0.382298   0.273830        NaN        NaN -0.959269
#        MR        -1.363237  -1.628483  -3.873175  -4.221600 -2.779734
#
#                   IME_MSE   DDE_MSE   DME_MSE
# N      estimand
# 100.0  Baseline  0.851550       NaN       NaN
#        Direct   -0.886683 -4.431907 -3.800038
#        IS1       0.317147  0.330792 -1.680913
#        IS2       0.803642       NaN       NaN
#        MR       -1.462263 -3.981849 -5.053495
# ...                   ...       ...       ...
# 1500.0 Baseline  0.361413       NaN       NaN
#        Direct   -2.862429 -3.176899 -2.772645
#        IS1       0.264886  0.289891 -1.576594
#        IS2       0.470265       NaN       NaN
#        MR       -3.510994 -7.024562 -7.475814
#
# [75 rows x 8 columns]

# %%
#Truncate does not matter 20 ok
import pickle
with open("estimate_additive_identity_L7_stdM_2_stdS_2_T.txt","rb") as fp:
    Error = pickle.load(fp)       
from plot import plot, summary
result = summary(Error, N_range = np.arange(1, 2) * 50, T_range = np.arange(1, 16) * 100, absolute = True, true = np.array([2.679841,3.653535,1.243782,0.689031]))
plot(result,x='T')
#result.groupby(['N','estimand']).mean()[['IDE_error','IME_error','DDE_error','DME_error',
#                                         'IDE_MSE','IME_MSE','DDE_MSE','DME_MSE']]

# %% [markdown]
# ####
